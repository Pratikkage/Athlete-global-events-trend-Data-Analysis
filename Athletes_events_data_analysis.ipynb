# %% [markdown]
# ## Athlete events Data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('athlete_events_combined.csv')
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal Region        Notes
# 0       Basketball Men's Basketball   NaN    CHN        China
# 1      Judo Men's Extra-Lightweight   NaN    CHN        China
# 2           Football Men's Football   NaN    DEN      Denmark
# 3       Tug-Of-War Men's Tug-Of-War  Gold    DEN      Denmark
# 4  Speed Skating Women's 500 metres   NaN    NED  Netherlands

# %%
df.info
# Out:
# <bound method DataFrame.info of             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal Region  \
# 0          Basketball               Basketball Men's Basketball   NaN    CHN
# 1                Judo              Judo Men's Extra-Lightweight   NaN    CHN
# 2            Football                   Football Men's Football   NaN    DEN
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold    DEN
# 4       Speed Skating          Speed Skating Women's 500 metres   NaN    NED
# ...               ...                                       ...   ...    ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   NaN    POL
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN    POL
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN    POL
# 271114      Bobsleigh                      Bobsleigh Men's Four   NaN    POL
# 271115      Bobsleigh                      Bobsleigh Men's Four   NaN    POL
#
#               Notes
# 0             China
# 1             China
# 2           Denmark
# 3           Denmark
# 4       Netherlands
# ...             ...
# 271111       Poland
# 271112       Poland
# 271113       Poland
# 271114       Poland
# 271115       Poland
#
# [271116 rows x 17 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
#  15  Region  270767 non-null  object
#  16  Notes   270746 non-null  object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 35.2+ MB

# %% [markdown]
# #### Calculating (mean, median, mode) for numerical columns  Age, Height, and Weight.

# %%
print("Mean of Ages :", df['Age'].mean())
print("Mean of Height :", df['Height'].mean())
print("Mean of Weight :", df['Weight'].mean())
# Out:
# Mean of Ages : 25.556898357297374
# Mean of Height : 175.33896987366376
# Mean of Weight : 70.70239290053351

# %% [markdown]
# #### Filtering the dataset to show only athletes who participated in the 1992 Summer Olympics.

# %%
(df[(df['Season'] == 'Summer') & (df['Year'] == 1992)])
# Out:
#             ID                                  Name Sex   Age  Height  \
# 0            1                             A Dijiang   M  24.0   180.0
# 96          33                   Mika Lauri Aarnikka   M  24.0   187.0
# 118         43                 Morten Gjerdrum Aasen   M  34.0   185.0
# 137         50                            Arvi Aavik   M  22.0   185.0
# 160         64                        M'Bairo Abakar   M  31.0     NaN
# ...        ...                                   ...  ..   ...     ...
# 271002  135514                          Tamara Zwart   F  17.0   167.0
# 271015  135523        Ronald Ferdinand "Ron" Zwerver   M  25.0   200.0
# 271027  135531  Sabine Beate Zwiener (-Jauchstetter)   F  24.0   172.0
# 271035  135537            Sawomir Andrzej Zwierzyski   M  25.0   175.0
# 271048  135545                       Henk Jan Zwolle   M  27.0   197.0
#
#         Weight         Team  NOC        Games  Year  Season       City  \
# 0         80.0        China  CHN  1992 Summer  1992  Summer  Barcelona
# 96        76.0      Finland  FIN  1992 Summer  1992  Summer  Barcelona
# 118       75.0       Norway  NOR  1992 Summer  1992  Summer  Barcelona
# 137      106.0      Estonia  EST  1992 Summer  1992  Summer  Barcelona
# 160        NaN         Chad  CHA  1992 Summer  1992  Summer  Barcelona
# ...        ...          ...  ...          ...   ...     ...        ...
# 271002    57.0  Netherlands  NED  1992 Summer  1992  Summer  Barcelona
# 271015    93.0  Netherlands  NED  1992 Summer  1992  Summer  Barcelona
# 271027    52.0      Germany  GER  1992 Summer  1992  Summer  Barcelona
# 271035    72.0       Poland  POL  1992 Summer  1992  Summer  Barcelona
# 271048    93.0  Netherlands  NED  1992 Summer  1992  Summer  Barcelona
#
#                         Sport                                    Event  \
# 0                  Basketball              Basketball Men's Basketball
# 96                    Sailing          Sailing Men's Two Person Dinghy
# 118             Equestrianism  Equestrianism Mixed Jumping, Individual
# 137                 Wrestling   Wrestling Men's Heavyweight, Freestyle
# 160                      Judo             Judo Men's Half-Middleweight
# ...                       ...                                      ...
# 271002  Synchronized Swimming       Synchronized Swimming Women's Duet
# 271015             Volleyball              Volleyball Men's Volleyball
# 271027              Athletics             Athletics Women's 800 metres
# 271035                Fencing                 Fencing Men's epee, Team
# 271048                 Rowing               Rowing Men's Double Sculls
#
#          Medal Region        Notes
# 0          NaN    CHN        China
# 96         NaN    FIN      Finland
# 118        NaN    NOR       Norway
# 137        NaN    EST      Estonia
# 160        NaN    CHA         Chad
# ...        ...    ...          ...
# 271002     NaN    NED  Netherlands
# 271015  Silver    NED  Netherlands
# 271027     NaN    GER      Germany
# 271035     NaN    POL       Poland
# 271048  Bronze    NED  Netherlands
#
# [12977 rows x 17 columns]

# %%
print("Toal number of records athletes who participated in the 1992 Summer Olympics : ", len(df[(df['Season'] == 'Summer') & (df['Year'] == 1992)]))
# Out:
# Toal number of records athletes who participated in the 1992 Summer Olympics :  12977

# %% [markdown]
# #### Count of unique teams (NOCs) in the dataset.

# %%
uniqe_noc = len(df['NOC'].unique())
print('Total number of unique records in NOC: ', uniqe_noc)
# Out:
# Total number of unique records in NOC:  230

# %% [markdown]
# #### Count of missing values in each column.

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# Region       349
# Notes        370
# dtype: int64

# %% [markdown]
# #### Group By Operations: Grouping data by 'Team' and calculating the average age of athletes for each team.

# %%
group = df.groupby('Team')['Age'].mean()
group
# Out:
# Team
# 30. Februar              33.500000
# A North American Team    41.333333
# Acipactli                47.333333
# Acturus                  27.000000
# Afghanistan              23.538462
#                            ...
# Zambia                   23.461039
# Zefyros                  35.500000
# Zimbabwe                 25.166124
# Zut                      32.000000
# rn-2                     29.200000
# Name: Age, Length: 1184, dtype: float64

# %% [markdown]
# #### Creating a bar plot showing the number of athletes per team.

# %%
data_vis = df['Team'].value_counts()
abc = data_vis.nlargest(10, keep = 'first')

# %%
plt.figure(figsize=(8, 4))
abc.plot(kind='bar', color='Brown')
plt.title('Number of Athletes per Team')
plt.xlabel('Team')
plt.ylabel('Number of Athletes')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Athletes data who won medal

# %%
medal_wons = df[df['Medal'].isin(['Bronze', 'Silver', 'Gold'])]
medal_wons
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 37          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 38          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 40          16             Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 41          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# ...        ...                                  ...  ..   ...     ...     ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0    80.0
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271082  135554                         Bogusaw Zych   M  28.0   182.0    82.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
#
#                   Team  NOC        Games  Year  Season       City       Sport  \
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris  Tug-Of-War
# 37             Finland  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 38             Finland  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 40             Finland  FIN  2014 Winter  2014  Winter      Sochi  Ice Hockey
# 41             Finland  FIN  1948 Summer  1948  Summer     London  Gymnastics
# ...                ...  ...          ...   ...     ...        ...         ...
# 271078    Soviet Union  URS  1956 Summer  1956  Summer  Melbourne   Athletics
# 271080    Soviet Union  URS  1964 Summer  1964  Summer      Tokyo   Athletics
# 271082          Poland  POL  1980 Summer  1980  Summer     Moskva     Fencing
# 271102          Russia  RUS  2000 Summer  2000  Summer     Sydney   Athletics
# 271103          Russia  RUS  2004 Summer  2004  Summer     Athina   Athletics
#
#                                          Event   Medal Region    Notes
# 3                  Tug-Of-War Men's Tug-Of-War    Gold    DEN  Denmark
# 37      Swimming Men's 200 metres Breaststroke  Bronze    FIN  Finland
# 38      Swimming Men's 400 metres Breaststroke  Bronze    FIN  Finland
# 40                 Ice Hockey Men's Ice Hockey  Bronze    FIN  Finland
# 41      Gymnastics Men's Individual All-Around  Bronze    FIN  Finland
# ...                                        ...     ...    ...      ...
# 271078              Athletics Women's Shot Put  Silver    URS   Russia
# 271080              Athletics Women's Shot Put  Bronze    URS   Russia
# 271082                Fencing Men's Foil, Team  Bronze    POL   Poland
# 271102  Athletics Women's 4 x 400 metres Relay  Bronze    RUS   Russia
# 271103  Athletics Women's 4 x 400 metres Relay  Silver    RUS   Russia
#
# [39783 rows x 17 columns]

# %% [markdown]
# #### Number of medals won by USA in each sport

# %%
medal_wons[(medal_wons['NOC'] == 'USA')].value_counts('Sport')
# Out:
# Sport
# Athletics                    1080
# Swimming                     1078
# Rowing                        375
# Basketball                    341
# Ice Hockey                    276
# Gymnastics                    194
# Shooting                      193
# Water Polo                    150
# Diving                        140
# Sailing                       140
# Equestrianism                 132
# Wrestling                     128
# Volleyball                    120
# Boxing                        113
# Football                      102
# Cycling                        78
# Bobsleigh                      74
# Speed Skating                  70
# Fencing                        69
# Baseball                       68
# Figure Skating                 66
# Tennis                         62
# Softball                       60
# Archery                        57
# Alpine Skiing                  44
# Weightlifting                  42
# Short Track Speed Skating      42
# Golf                           38
# Rugby                          36
# Hockey                         30
# Synchronized Swimming          30
# Snowboarding                   24
# Freestyle Skiing               21
# Canoeing                       21
# Beach Volleyball               20
# Modern Pentathlon              17
# Tug-Of-War                     14
# Judo                           14
# Polo                           12
# Lacrosse                       12
# Luge                            9
# Taekwondo                       9
# Art Competitions                9
# Skeleton                        8
# Nordic Combined                 7
# Curling                         4
# Roque                           3
# Triathlon                       2
# Ski Jumping                     1
# Cross Country Skiing            1
# Jeu De Paume                    1
# Name: count, dtype: int64

# %% [markdown]
# ### Athletes winning medal in Winter olympics

# %%
medal_wons[(medal_wons['Season'] == 'Winter')]
# Out:
#             ID                       Name Sex   Age  Height  Weight  \
# 40          16   Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 60          20         Kjetil Andr Aamodt   M  20.0   176.0    85.0
# 61          20         Kjetil Andr Aamodt   M  20.0   176.0    85.0
# 63          20         Kjetil Andr Aamodt   M  22.0   176.0    85.0
# 64          20         Kjetil Andr Aamodt   M  22.0   176.0    85.0
# ...        ...                        ...  ..   ...     ...     ...
# 270641  135355  Sergey Mikhaylovich Zubov   M  21.0   186.0    91.0
# 270827  135447                Matja Zupan   M  19.0   179.0    60.0
# 270876  135465          Pirmin Zurbriggen   M  25.0   183.0    83.0
# 270878  135465          Pirmin Zurbriggen   M  25.0   183.0    83.0
# 270886  135467          Silvan Zurbriggen   M  28.0   185.0    94.0
#
#                 Team  NOC        Games  Year  Season         City  \
# 40           Finland  FIN  2014 Winter  2014  Winter        Sochi
# 60            Norway  NOR  1992 Winter  1992  Winter  Albertville
# 61            Norway  NOR  1992 Winter  1992  Winter  Albertville
# 63            Norway  NOR  1994 Winter  1994  Winter  Lillehammer
# 64            Norway  NOR  1994 Winter  1994  Winter  Lillehammer
# ...              ...  ...          ...   ...     ...          ...
# 270641  Unified Team  EUN  1992 Winter  1992  Winter  Albertville
# 270827    Yugoslavia  YUG  1988 Winter  1988  Winter      Calgary
# 270876   Switzerland  SUI  1988 Winter  1988  Winter      Calgary
# 270878   Switzerland  SUI  1988 Winter  1988  Winter      Calgary
# 270886   Switzerland  SUI  2010 Winter  2010  Winter    Vancouver
#
#                 Sport                               Event   Medal Region  \
# 40         Ice Hockey         Ice Hockey Men's Ice Hockey  Bronze    FIN
# 60      Alpine Skiing         Alpine Skiing Men's Super G    Gold    NOR
# 61      Alpine Skiing    Alpine Skiing Men's Giant Slalom  Bronze    NOR
# 63      Alpine Skiing        Alpine Skiing Men's Downhill  Silver    NOR
# 64      Alpine Skiing         Alpine Skiing Men's Super G  Bronze    NOR
# ...               ...                                 ...     ...    ...
# 270641     Ice Hockey         Ice Hockey Men's Ice Hockey    Gold    EUN
# 270827    Ski Jumping  Ski Jumping Men's Large Hill, Team  Silver    YUG
# 270876  Alpine Skiing        Alpine Skiing Men's Downhill    Gold    SUI
# 270878  Alpine Skiing    Alpine Skiing Men's Giant Slalom  Bronze    SUI
# 270886  Alpine Skiing        Alpine Skiing Men's Combined  Bronze    SUI
#
#               Notes
# 40          Finland
# 60           Norway
# 61           Norway
# 63           Norway
# 64           Norway
# ...             ...
# 270641       Russia
# 270827       Serbia
# 270876  Switzerland
# 270878  Switzerland
# 270886  Switzerland
#
# [5695 rows x 17 columns]

# %% [markdown]
# #### Top Performers: Top 5 teams with the most gold medals.

# %%
gold_medalists = df[df['Medal'] == 'Gold']

gold_medal_counts = gold_medalists['Team'].value_counts()

top_5_teams = gold_medal_counts.nlargest(5)

print(top_5_teams)
# Out:
# Team
# United States    2474
# Soviet Union     1058
# Germany           679
# Italy             535
# Great Britain     519
# Name: count, dtype: int64

# %% [markdown]
# #### Height and Weight Analysis : relationship between height and weight of athletes.

# %%
colors = ["Red", "Blue"]
plt.scatter(df['Height'], df['Weight'])
plt.xlabel('Height')
plt.xlabel('Weight')
plt.show()

# %% [markdown]
# #### Highest number participants by sports

# %%
df.groupby('Sport').size().sort_values( ascending = False)
# Out:
# Sport
# Athletics        38624
# Gymnastics       26707
# Swimming         23195
# Shooting         11448
# Cycling          10859
#                  ...
# Racquets            12
# Jeu De Paume        11
# Roque                4
# Basque Pelota        2
# Aeronautics          1
# Length: 66, dtype: int64

# %% [markdown]
# ## Analyzing the trend of yearly number of Participants using Linear Regression

# %%
#Data pre-processing
c1 = df[['Year']].value_counts()
c1.to_csv('yearwise_athlets.csv')
c1
# Out:
# Year
# 1992    16413
# 1988    14676
# 2000    13821
# 1996    13780
# 2016    13688
# 2008    13602
# 2004    13443
# 2012    12920
# 1972    11959
# 1984    11588
# 1976    10502
# 1968    10479
# 1964     9480
# 1952     9358
# 1960     9235
# 1980     8937
# 1948     7480
# 1936     7401
# 1956     6434
# 1924     5693
# 1928     5574
# 2014     4891
# 2010     4402
# 2006     4382
# 1920     4292
# 2002     4109
# 1912     4040
# 1998     3605
# 1932     3321
# 1994     3160
# 1908     3101
# 1900     1936
# 1906     1733
# 1904     1301
# 1896      380
# Name: count, dtype: int64

# %%
data = pd.read_csv('yearwise_athlets.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    35 non-null     int64
#  1   count   35 non-null     int64
# dtypes: int64(2)
# memory usage: 692.0 bytes

# %%
#naming the new columns
data.columns = ["Year", "Participants"]

# %%
#visualizing the data
plt.scatter(data['Year'], data['Participants'])
plt.xlabel('years')
plt.ylabel('Participents')
plt.grid()

# %%
data.sort_values('Year')
# Out:
#     Year  Participants
# 34  1896           380
# 31  1900          1936
# 33  1904          1301
# 32  1906          1733
# 30  1908          3101
# 26  1912          4040
# 24  1920          4292
# 19  1924          5693
# 20  1928          5574
# 28  1932          3321
# 17  1936          7401
# 16  1948          7480
# 13  1952          9358
# 18  1956          6434
# 14  1960          9235
# 12  1964          9480
# 11  1968         10479
# 8   1972         11959
# 10  1976         10502
# 15  1980          8937
# 9   1984         11588
# 1   1988         14676
# 0   1992         16413
# 29  1994          3160
# 3   1996         13780
# 27  1998          3605
# 2   2000         13821
# 25  2002          4109
# 6   2004         13443
# 23  2006          4382
# 5   2008         13602
# 22  2010          4402
# 7   2012         12920
# 21  2014          4891
# 4   2016         13688

# %%
#removing outliers manually
data = data.drop(data[(data['Year'] == 1994) | 
(data['Year'] == 1998) | 
(data['Year'] == 2002) | 
(data['Year'] == 2006) | 
(data['Year'] == 2010) | 
(data['Year'] == 2014)].index)
data
# Out:
#     Year  Participants
# 0   1992         16413
# 1   1988         14676
# 2   2000         13821
# 3   1996         13780
# 4   2016         13688
# 5   2008         13602
# 6   2004         13443
# 7   2012         12920
# 8   1972         11959
# 9   1984         11588
# 10  1976         10502
# 11  1968         10479
# 12  1964          9480
# 13  1952          9358
# 14  1960          9235
# 15  1980          8937
# 16  1948          7480
# 17  1936          7401
# 18  1956          6434
# 19  1924          5693
# 20  1928          5574
# 24  1920          4292
# 26  1912          4040
# 28  1932          3321
# 30  1908          3101
# 31  1900          1936
# 32  1906          1733
# 33  1904          1301
# 34  1896           380

# %%
#cross-checking the data after removing ouliers
plt.scatter(data['Year'], data['Participants'])
plt.xlabel('years')
plt.ylabel('Participants')
plt.grid()

# %%
#importing libraries required for linear regression
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

var = linear_model.LinearRegression()

#fitting the data
var.fit(data[['Year']], data['Participants'])
# Out:
# LinearRegression()

# %%
#checking the score
var.score(data[['Year']], data['Participants'])
# Out:
# 0.908229968895147

# %%
#Enter the year for prediction
var.predict([[2024]])
# Out:
# C:\Users\compaid sangli\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([16408.1326127])
